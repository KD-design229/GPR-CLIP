# %%
# 1. 安装依赖
# !pip install -r requirements.txt

# %%
# 2. 检查 GPU
# !nvidia-smi

# %%
# 3. 运行训练
# 参数说明：
# --dataset gpr_custom: 使用自定义数据集
# --data_dir /kaggle/input/my-gpr-dataset: 数据集路径 (请修改为你实际的路径)
# --num_classes 8: 类别数量
# --client_num 4: 客户端数量
# --gpu 0: 使用第一个 GPU

# !python main.py \
    --dataset gpr_custom \
    --data_dir /kaggle/input/my-gpr-dataset \
    --model cnn \
    --client_num 4 \
    --gpu 0 \
    --num_classes 8 \
    --Tg 50 \
    --E 1 \
    --lr 0.01
